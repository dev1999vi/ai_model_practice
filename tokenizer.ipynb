# %%
import tiktoken

# %%
tokenizer = tiktoken.get_encoding("cl100k_base")

# %%
tokenizer
# Out:
# <Encoding 'cl100k_base'>

# %%
tokenizer.encode("Hello World!")
# Out:
# [9906, 4435, 0]

# %%
tokenizer.decode([9906, 4435, 0])
# Out:
# 'Hello World!'
